# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salesdata = pd.read_csv('totalsales.csv')
salesdata.head()
# Out:
#    id             name  value  Quantity
# 0  10           Ginger   1650    108084
# 1  11  Passion Fruits    1860    107848
# 2  12       Pineapples   2200    109512
# 3  13      Green Grams   2300    111027
# 4  14            Guava   2000    107078

# %%
salesdata
# Out:
#     id             name  value  Quantity
# 0   10           Ginger   1650    108084
# 1   11  Passion Fruits    1860    107848
# 2   12       Pineapples   2200    109512
# 3   13      Green Grams   2300    111027
# 4   14            Guava   2000    107078
# 5   15             eggs    300    108103
# 6   16            Sugar   4000    109349
# 7   17         Soybeans   2000    106847
# 8   18           Coffee   3200    108698
# 9   19              Tea   3000    110546
# 10  20          Oranges   2050    110775
# 11  21            Wheat   4000    110782
# 12  22        Cucumbers   3000    111035
# 13  23     Strawberries   2300    112555
# 14  24           Lemons   2400    109790
# 15  25          Lettuce   3000    109528

# %%
print(salesdata.to_string(index=False))# prints the table to string form
# Out:
# id             name  value  Quantity
# 10           Ginger   1650    108084
# 11  Passion Fruits    1860    107848
# 12       Pineapples   2200    109512
# 13      Green Grams   2300    111027
# 14            Guava   2000    107078
# 15             eggs    300    108103
# 16            Sugar   4000    109349
# 17         Soybeans   2000    106847
# 18           Coffee   3200    108698
# 19              Tea   3000    110546
# 20          Oranges   2050    110775
# 21            Wheat   4000    110782
# 22        Cucumbers   3000    111035
# 23     Strawberries   2300    112555
# 24           Lemons   2400    109790
# 25          Lettuce   3000    109528

# %%
#creating a table that takes the id and quantitys so as to be able to plot it 
newsd = salesdata[['value','Quantity']]
newsd
# Out:
#     value  Quantity
# 0    1650    108084
# 1    1860    107848
# 2    2200    109512
# 3    2300    111027
# 4    2000    107078
# 5     300    108103
# 6    4000    109349
# 7    2000    106847
# 8    3200    108698
# 9    3000    110546
# 10   2050    110775
# 11   4000    110782
# 12   3000    111035
# 13   2300    112555
# 14   2400    109790
# 15   3000    109528

# %%
plt.plot(newsd['Quantity'])

# %%
plt.show();
